# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('train.csv')

# %%
data.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# 0                       5  ...        1921                0       122003
# 1                       5  ...        1909                0       122004
# 2                       3  ...        1939                0       122004
# 3                       3  ...        2001                0       122005
# 4                       4  ...        1929                0       122006
#
#    Lattitude  Longitude  living_area_renov  lot_area_renov  \
# 0    52.8645   -114.557               2880            5400
# 1    52.8878   -114.470               2470            4000
# 2    52.8852   -114.468               2940            6600
# 3    52.9532   -114.321               3350           42847
# 4    52.9047   -114.485               2060            4500
#
#    Number of schools nearby  Distance from the airport    Price
# 0                         2                         58  2380000
# 1                         2                         51  1400000
# 2                         1                         53  1200000
# 3                         3                         76   838000
# 4                         1                         51   805000
#
# [5 rows x 23 columns]

# %%
data.shape
# Out:
# (14620, 23)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
#  10  grade of the house                     14620 non-null  int64
#  11  Area of the house(excluding basement)  14620 non-null  int64
#  12  Area of the basement                   14620 non-null  int64
#  13  Built Year                             14620 non-null  int64
#  14  Renovation Year                        14620 non-null  int64
#  15  Postal Code                            14620 non-null  int64
#  16  Lattitude                              14620 non-null  float64
#  17  Longitude                              14620 non-null  float64
#  18  living_area_renov                      14620 non-null  int64
#  19  lot_area_renov                         14620 non-null  int64
#  20  Number of schools nearby               14620 non-null  int64
#  21  Distance from the airport              14620 non-null  int64
#  22  Price                                  14620 non-null  int64
# dtypes: float64(4), int64(19)
# memory usage: 2.6 MB

# %%
for column in data.columns:
    print(data[column].value_counts())
    print("*"*23)
# Out:
# id
# 6762810145    1
# 6762812541    1
# 6762813736    1
# 6762813785    1
# 6762814009    1
#              ..
# 6762812356    1
# 6762812410    1
# 6762812471    1
# 6762812563    1
# 6762831463    1
# Name: count, Length: 14620, dtype: int64
# ***********************
# Date
# 42543    142
# 42546    131
# 42545    131
# 42558    127
# 42559    121
#         ...
# 42675      1
# 42506      1
# 42584      1
# 42577      1
# 42611      1
# Name: count, Length: 241, dtype: int64
# ***********************
# number of bedrooms
# 3     6612
# 4     4724
# 2     1844
# 5     1079
# 6      176
# 1      136
# 7       30
# 8       11
# 9        3
# 10       3
# 33       1
# 11       1
# Name: count, dtype: int64
# ***********************
# number of bathrooms
# 2.50    3678
# 1.00    2509
# 1.75    2062
# 2.25    1378
# 2.00    1323
# 1.50     968
# 2.75     831
# 3.00     510
# 3.50     504
# 3.25     424
# 3.75     101
# 4.00      81
# 4.50      72
# 4.25      56
# 0.75      47
# 4.75      17
# 5.00      15
# 5.25      12
# 5.50       8
# 1.25       7
# 0.50       3
# 6.00       3
# 8.00       2
# 5.75       2
# 6.25       2
# 6.75       2
# 6.50       1
# 7.50       1
# 7.75       1
# Name: count, dtype: int64
# ***********************
# living area
# 1400    93
# 1010    92
# 1320    91
# 1660    90
# 1820    88
#         ..
# 2448     1
# 2846     1
# 5320     1
# 5930     1
# 1556     1
# Name: count, Length: 865, dtype: int64
# ***********************
# lot area
# 5000     269
# 6000     176
# 4000     172
# 7200     149
# 7500      82
#         ...
# 5022       1
# 10961      1
# 5823       1
# 11072      1
# 6621       1
# Name: count, Length: 7451, dtype: int64
# ***********************
# number of floors
# 1.0    7103
# 2.0    5666
# 1.5    1311
# 3.0     418
# 2.5     118
# 3.5       4
# Name: count, dtype: int64
# ***********************
# waterfront present
# 0    14508
# 1      112
# Name: count, dtype: int64
# ***********************
# number of views
# 0    13198
# 2      636
# 3      351
# 1      219
# 4      216
# Name: count, dtype: int64
# ***********************
# condition of the house
# 3    9350
# 4    3874
# 5    1278
# 2     100
# 1      18
# Name: count, dtype: int64
# ***********************
# grade of the house
# 7     6011
# 8     4137
# 9     1828
# 6     1324
# 10     804
# 11     280
# 5      154
# 12      55
# 4       17
# 13      10
# Name: count, dtype: int64
# ***********************
# Area of the house(excluding basement)
# 1010    146
# 1200    138
# 1300    138
# 1140    127
# 1400    126
#        ...
# 3274      1
# 4475      1
# 1256      1
# 1087      1
# 1556      1
# Name: count, Length: 781, dtype: int64
# ***********************
# Area of the basement
# 0       8842
# 800      157
# 600      148
# 700      147
# 500      146
#         ...
# 276        1
# 768        1
# 2190       1
# 1840       1
# 1930       1
# Name: count, Length: 280, dtype: int64
# ***********************
# Built Year
# 2014    404
# 2005    319
# 2006    300
# 2004    296
# 2003    295
#        ...
# 1902     20
# 1935     18
# 1933     17
# 1934     15
# 2015     12
# Name: count, Length: 116, dtype: int64
# ***********************
# Renovation Year
# 0       13954
# 2014       76
# 2013       30
# 2003       27
# 2005       23
#         ...
# 1948        1
# 1967        1
# 1944        1
# 1959        1
# 1962        1
# Name: count, Length: 68, dtype: int64
# ***********************
# Postal Code
# 122028    432
# 122005    416
# 122006    397
# 122007    396
# 122033    383
#          ...
# 122013     77
# 122062     62
# 122036     49
# 122060     39
# 122071     37
# Name: count, Length: 70, dtype: int64
# ***********************
# Lattitude
# 52.7745    13
# 52.8947    13
# 52.9255    13
# 52.9146    13
# 52.8834    13
#            ..
# 52.8969     1
# 52.6834     1
# 52.5337     1
# 52.6155     1
# 52.5338     1
# Name: count, Length: 4662, dtype: int64
# ***********************
# Longitude
# -114.552    73
# -114.562    73
# -114.490    72
# -114.480    69
# -114.553    68
#             ..
# -114.036     1
# -114.096     1
# -113.994     1
# -114.111     1
# -113.891     1
# Name: count, Length: 716, dtype: int64
# ***********************
# living_area_renov
# 1440    136
# 1540    131
# 1560    127
# 1500    122
# 1510    117
#        ...
# 2029      1
# 2634      1
# 1137      1
# 1537      1
# 1162      1
# Name: count, Length: 665, dtype: int64
# ***********************
# lot_area_renov
# 5000      301
# 4000      256
# 6000      179
# 7200      138
# 4800      102
#          ...
# 12068       1
# 185565      1
# 60112       1
# 14564       1
# 6631        1
# Name: count, Length: 6835, dtype: int64
# ***********************
# Number of schools nearby
# 3    4973
# 2    4853
# 1    4794
# Name: count, dtype: int64
# ***********************
# Distance from the airport
# 54    514
# 70    511
# 64    500
# 50    495
# 79    487
# 60    486
# 67    485
# 56    484
# 53    484
# 59    482
# 69    481
# 58    474
# 55    473
# 74    471
# 72    471
# 66    470
# 62    470
# 57    467
# 73    466
# 75    466
# 71    465
# 77    465
# 78    461
# 76    458
# 80    454
# 63    453
# 68    449
# 52    447
# 65    446
# 61    443
# 51    442
# Name: count, dtype: int64
# ***********************
# Price
# 450000    114
# 350000    113
# 400000    104
# 375000    103
# 550000    102
#          ...
# 561600      1
# 856500      1
# 907687      1
# 307999      1
# 146000      1
# Name: count, Length: 2901, dtype: int64
# ***********************

# %%
data.isna().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# Price                                    0
# dtype: int64

# %%
data.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# min      370.000000  5.200000e+02          1.000000            0.000000
# 25%     1440.000000  5.010750e+03          1.000000            0.000000
# 50%     1930.000000  7.620000e+03          1.500000            0.000000
# 75%     2570.000000  1.080000e+04          2.000000            0.000000
# max    13540.000000  1.074218e+06          3.500000            1.000000
#
#        number of views  condition of the house  ...    Built Year  \
# count     14620.000000            14620.000000  ...  14620.000000
# mean          0.233105                3.430506  ...   1970.926402
# std           0.766259                0.664151  ...     29.493625
# min           0.000000                1.000000  ...   1900.000000
# 25%           0.000000                3.000000  ...   1951.000000
# 50%           0.000000                3.000000  ...   1975.000000
# 75%           0.000000                4.000000  ...   1997.000000
# max           4.000000                5.000000  ...   2015.000000
#
#        Renovation Year    Postal Code     Lattitude     Longitude  \
# count     14620.000000   14620.000000  14620.000000  14620.000000
# mean         90.924008  122033.062244     52.792848   -114.404007
# std         416.216661      19.082418      0.137522      0.141326
# min           0.000000  122003.000000     52.385900   -114.709000
# 25%           0.000000  122017.000000     52.707600   -114.519000
# 50%           0.000000  122032.000000     52.806400   -114.421000
# 75%           0.000000  122048.000000     52.908900   -114.315000
# max        2015.000000  122072.000000     53.007600   -113.505000
#
#        living_area_renov  lot_area_renov  Number of schools nearby  \
# count       14620.000000    14620.000000              14620.000000
# mean         1996.702257    12753.500068                  2.012244
# std           691.093366    26058.414467                  0.817284
# min           460.000000      651.000000                  1.000000
# 25%          1490.000000     5097.750000                  1.000000
# 50%          1850.000000     7620.000000                  2.000000
# 75%          2380.000000    10125.000000                  3.000000
# max          6110.000000   560617.000000                  3.000000
#
#        Distance from the airport         Price
# count               14620.000000  1.462000e+04
# mean                   64.950958  5.389322e+05
# std                     8.936008  3.675324e+05
# min                    50.000000  7.800000e+04
# 25%                    57.000000  3.200000e+05
# 50%                    65.000000  4.500000e+05
# 75%                    73.000000  6.450000e+05
# max                    80.000000  7.700000e+06
#
# [8 rows x 23 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
#  10  grade of the house                     14620 non-null  int64
#  11  Area of the house(excluding basement)  14620 non-null  int64
#  12  Area of the basement                   14620 non-null  int64
#  13  Built Year                             14620 non-null  int64
#  14  Renovation Year                        14620 non-null  int64
#  15  Postal Code                            14620 non-null  int64
#  16  Lattitude                              14620 non-null  float64
#  17  Longitude                              14620 non-null  float64
#  18  living_area_renov                      14620 non-null  int64
#  19  lot_area_renov                         14620 non-null  int64
#  20  Number of schools nearby               14620 non-null  int64
#  21  Distance from the airport              14620 non-null  int64
#  22  Price                                  14620 non-null  int64
# dtypes: float64(4), int64(19)
# memory usage: 2.6 MB

# %%
data['number of bedrooms'].value_counts()
# Out:
# number of bedrooms
# 3     6612
# 4     4724
# 2     1844
# 5     1079
# 6      176
# 1      136
# 7       30
# 8       11
# 9        3
# 10       3
# 33       1
# 11       1
# Name: count, dtype: int64

# %%
data.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# 0                       5  ...        1921                0       122003
# 1                       5  ...        1909                0       122004
# 2                       3  ...        1939                0       122004
# 3                       3  ...        2001                0       122005
# 4                       4  ...        1929                0       122006
#
#    Lattitude  Longitude  living_area_renov  lot_area_renov  \
# 0    52.8645   -114.557               2880            5400
# 1    52.8878   -114.470               2470            4000
# 2    52.8852   -114.468               2940            6600
# 3    52.9532   -114.321               3350           42847
# 4    52.9047   -114.485               2060            4500
#
#    Number of schools nearby  Distance from the airport    Price
# 0                         2                         58  2380000
# 1                         2                         51  1400000
# 2                         1                         53  1200000
# 3                         3                         76   838000
# 4                         1                         51   805000
#
# [5 rows x 23 columns]

# %%
data['price_per_sqft']=data['Price']*100000/data['living area']

# %%
data.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# min      370.000000  5.200000e+02          1.000000            0.000000
# 25%     1440.000000  5.010750e+03          1.000000            0.000000
# 50%     1930.000000  7.620000e+03          1.500000            0.000000
# 75%     2570.000000  1.080000e+04          2.000000            0.000000
# max    13540.000000  1.074218e+06          3.500000            1.000000
#
#        number of views  condition of the house  ...  Renovation Year  \
# count     14620.000000            14620.000000  ...     14620.000000
# mean          0.233105                3.430506  ...        90.924008
# std           0.766259                0.664151  ...       416.216661
# min           0.000000                1.000000  ...         0.000000
# 25%           0.000000                3.000000  ...         0.000000
# 50%           0.000000                3.000000  ...         0.000000
# 75%           0.000000                4.000000  ...         0.000000
# max           4.000000                5.000000  ...      2015.000000
#
#          Postal Code     Lattitude     Longitude  living_area_renov  \
# count   14620.000000  14620.000000  14620.000000       14620.000000
# mean   122033.062244     52.792848   -114.404007        1996.702257
# std        19.082418      0.137522      0.141326         691.093366
# min    122003.000000     52.385900   -114.709000         460.000000
# 25%    122017.000000     52.707600   -114.519000        1490.000000
# 50%    122032.000000     52.806400   -114.421000        1850.000000
# 75%    122048.000000     52.908900   -114.315000        2380.000000
# max    122072.000000     53.007600   -113.505000        6110.000000
#
#        lot_area_renov  Number of schools nearby  Distance from the airport  \
# count    14620.000000              14620.000000               14620.000000
# mean     12753.500068                  2.012244                  64.950958
# std      26058.414467                  0.817284                   8.936008
# min        651.000000                  1.000000                  50.000000
# 25%       5097.750000                  1.000000                  57.000000
# 50%       7620.000000                  2.000000                  65.000000
# 75%      10125.000000                  3.000000                  73.000000
# max     560617.000000                  3.000000                  80.000000
#
#               Price  price_per_sqft
# count  1.462000e+04    1.462000e+04
# mean   5.389322e+05    2.605790e+07
# std    3.675324e+05    1.060492e+07
# min    7.800000e+04    8.758824e+06
# 25%    3.200000e+05    1.816063e+07
# 50%    4.500000e+05    2.426377e+07
# 75%    6.450000e+05    3.141696e+07
# max    7.700000e+06    8.000000e+07
#
# [8 rows x 24 columns]

# %%
data.shape
# Out:
# (14620, 24)

# %%
data
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# 1             2920      4000               1.5                   0
# 2             2910      9480               1.5                   0
# 3             3310     42998               2.0                   0
# 4             2710      4500               1.5                   0
# ...            ...       ...               ...                 ...
# 14615         1556     20000               1.0                   0
# 14616         1680      7000               1.5                   0
# 14617         1070      6120               1.0                   0
# 14618         1030      6621               1.0                   0
# 14619          900      4770               1.0                   0
#
#        number of views  condition of the house  ...  Renovation Year  \
# 0                    4                       5  ...                0
# 1                    0                       5  ...                0
# 2                    0                       3  ...                0
# 3                    0                       3  ...                0
# 4                    0                       4  ...                0
# ...                ...                     ...  ...              ...
# 14615                0                       4  ...                0
# 14616                0                       4  ...                0
# 14617                0                       3  ...                0
# 14618                0                       4  ...                0
# 14619                0                       3  ...             2009
#
#        Postal Code  Lattitude  Longitude  living_area_renov  lot_area_renov  \
# 0           122003    52.8645   -114.557               2880            5400
# 1           122004    52.8878   -114.470               2470            4000
# 2           122004    52.8852   -114.468               2940            6600
# 3           122005    52.9532   -114.321               3350           42847
# 4           122006    52.9047   -114.485               2060            4500
# ...            ...        ...        ...                ...             ...
# 14615       122066    52.6191   -114.472               2250           17286
# 14616       122072    52.5075   -114.393               1540            7480
# 14617       122056    52.7289   -114.507               1130            6120
# 14618       122042    52.7157   -114.411               1420            6631
# 14619       122018    52.5338   -114.552                900            3480
#
#        Number of schools nearby  Distance from the airport    Price  \
# 0                             2                         58  2380000
# 1                             2                         51  1400000
# 2                             1                         53  1200000
# 3                             3                         76   838000
# 4                             1                         51   805000
# ...                         ...                        ...      ...
# 14615                         3                         76   221700
# 14616                         3                         59   219200
# 14617                         2                         64   209000
# 14618                         3                         54   205000
# 14619                         2                         55   146000
#
#        price_per_sqft
# 0        6.520548e+07
# 1        4.794521e+07
# 2        4.123711e+07
# 3        2.531722e+07
# 4        2.970480e+07
# ...               ...
# 14615    1.424807e+07
# 14616    1.304762e+07
# 14617    1.953271e+07
# 14618    1.990291e+07
# 14619    1.622222e+07
#
# [14620 rows x 24 columns]

# %%
data.drop(columns=['price_per_sqft'],inplace=True)

# %%
data.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# 0                       5  ...        1921                0       122003
# 1                       5  ...        1909                0       122004
# 2                       3  ...        1939                0       122004
# 3                       3  ...        2001                0       122005
# 4                       4  ...        1929                0       122006
#
#    Lattitude  Longitude  living_area_renov  lot_area_renov  \
# 0    52.8645   -114.557               2880            5400
# 1    52.8878   -114.470               2470            4000
# 2    52.8852   -114.468               2940            6600
# 3    52.9532   -114.321               3350           42847
# 4    52.9047   -114.485               2060            4500
#
#    Number of schools nearby  Distance from the airport    Price
# 0                         2                         58  2380000
# 1                         2                         51  1400000
# 2                         1                         53  1200000
# 3                         3                         76   838000
# 4                         1                         51   805000
#
# [5 rows x 23 columns]

# %%
data.to_csv("final_dataset.csv")

# %%
X=data.drop(columns=['Price'])
y=data['Price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.preprocessing import OneHotEncoder , StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (11696, 22)
# (11696,)

# %%
column_trans=make_column_transformer((OneHotEncoder(sparse=False),['number of bedrooms']),remainder='passthrough')

# %%
scaler=StandardScaler()

# %%
lr=LinearRegression(normalize=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 lr=LinearRegression(normalize=True)
#
# TypeError: LinearRegression.__init__() got an unexpected keyword argument 'normalize'

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)
lr=LinearRegression()
lr.fit(X_scaled,y)
# Out:
# LinearRegression()

# %%
pipe=make_pipeline(column_trans,scaler,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# C:\Users\S.V.Janani\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['number of bedrooms'])])),
#                 ('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
y_pred_lr=pipe.predict(X_test)

# %%
r2_score(y_test,y_pred_lr)
# Out:
# 0.7171872425138786

# %%
lasso = Lasso()

# %%
pipe=make_pipeline(column_trans,scaler,lasso)

# %%
pipe.fit(X_train,y_train)
# Out:
# C:\Users\S.V.Janani\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\S.V.Janani\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.995e+13, tolerance: 1.569e+11
#   model = cd_fast.enet_coordinate_descent(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['number of bedrooms'])])),
#                 ('standardscaler', StandardScaler()), ('lasso', Lasso())])

# %%
y_pred_lasso=pipe.predict(X_test)
r2_score(y_test,y_pred_lasso)
# Out:
# 0.7171801195543877

# %%
r2_score(y_test,y_pred_lasso)
# Out:
# 0.7171801195543877

# %%
ridge = Ridge()

# %%
pipe=make_pipeline(column_trans,scaler,ridge)

# %%
pipe.fit(X_train,y_train)
# Out:
# C:\Users\S.V.Janani\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['number of bedrooms'])])),
#                 ('standardscaler', StandardScaler()), ('ridge', Ridge())])

# %%
y_pred_ridge=pipe.predict(X_test)
r2_score(y_test,y_pred_ridge)
# Out:
# 0.7171806329505703

# %%
print("No Regularization:",r2_score(y_test,y_pred_lr))
print("Lasso:",r2_score(y_test,y_pred_lasso))
print("Ridge:",r2_score(y_test,y_pred_ridge))
# Out:
# No Regularization: 0.7171872425138786
# Lasso: 0.7171801195543877
# Ridge: 0.7171806329505703

# %%
import pickle

# %%
pickle.dump(pipe,open('RidgeModel.pkl','wb'))
